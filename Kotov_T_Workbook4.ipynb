# %%
import numpy as np
from numpy import fromfile, linspace, vstack, ones
from numpy.random import rand
import matplotlib.pyplot as plt


delta = 1.0
x = linspace(-5,5,11)
y = x**2 + delta * (rand(11) - 0.5)
x += delta * (rand(11) - 0.5)

x.tofile('x_data.txt','\n')
y.tofile('y_data.txt','\n')

x = fromfile('x_data.txt', float, sep='\n')
y = fromfile('y_data.txt', float, sep='\n')

m = vstack((x**3, x**2, x, ones(11))).T
s = np.linalg.lstsq(m, y, rcond = None)[0]
plt.figure(1)
x_prec = linspace(-5, 5, 101)
plt.plot(x, y, 'D')

plt.plot(x_prec, s[0] * x_prec**3 + s[1] * x_prec**2 + s[2]*x_prec + s[3], '-', lw=3)
plt.grid()


####################################################

delta = 1.0
x = linspace(-5,5,11)
y = x**2 + delta * (rand(11) - 0.5)
x += delta * (rand(11) - 0.5)

x.tofile('x_data2.txt','\n')
y.tofile('y_data2.txt','\n')

x = fromfile('x_data2.txt', float, sep='\n')
y = fromfile('y_data2.txt', float, sep='\n')

m = vstack((x**2, x, ones(11))).T
s = np.linalg.lstsq(m, y, rcond = None)[0]
plt.figure(2)
x_prec = linspace(-5, 5, 101)
plt.plot(x, y, 'D')

plt.plot(x_prec, s[0] * x_prec**2 + s[1]*x_prec + s[2], '-', lw=2)
plt.grid()
plt.savefig('полином 2-й степени.png')
plt.show()

####################################################

delta = 1.0
x = linspace(-5,5,11)
y = x + delta * (rand(11) - 0.5)
x += delta * (rand(11) - 0.5)

x.tofile('x_data3.txt','\n')
y.tofile('y_data3.txt','\n')

x = fromfile('x_data3.txt', float, sep='\n')
y = fromfile('y_data3.txt', float, sep='\n')

m = vstack((x, ones(11))).T
s = np.linalg.lstsq(m, y, rcond = None)[0]
plt.figure(2)
x_prec = linspace(-5, 5, 101)
plt.plot(x, y, 'D')

plt.plot(x_prec, s[0]*x_prec + s[1], '-', lw=3)
plt.grid()
plt.savefig('полином 3-й степени.png')
plt.show()

# %%
import numpy as np
import scipy as sp

beta = (0.25, 0.75)
def f(x, b0, b1):
    return b0 + b1 * x
xdata = np.linspace(0, 5, 50)
y = f(xdata, *beta)
ydata = y + 0.05 * np.random.randn(len(xdata))
beta_opt, beta_cov = sp.optimize.curve_fit(f, xdata, ydata)
print(beta_opt)
lin_dev = sum(beta_cov[0])
print(lin_dev)
residuals = ydata - f(xdata, *beta_opt) 
fres = sum(residuals**2)
print(fres)

fig, ax = plt.subplots() 
ax.scatter(xdata, ydata) 
ax.plot(xdata, y, 'r', lw=2) 
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2) 
ax.set_xlim(0, 5) 
ax.set_xlabel(r"$x$", fontsize=18) 
ax.set_ylabel(r"$f(x, \beta)$", fontsize=18) 
plt.show()


beta = (0.25, 0.75, 0.5) 
def f(x, b0, b1, b2): 
    return b0 + b1 * x + b2 * x * x
xdata = np.linspace(1.5, 15, 50) 
y = f(xdata, *beta)
ydata = y + 0.05 * np.random.randn(len(xdata))
beta_opt, beta_cov = sp.optimize.curve_fit(f, xdata, ydata)
print(beta_opt) 
lin_dev = sum(beta_cov[0])
print(lin_dev)
residuals = ydata - f(xdata, *beta_opt) 
fres = sum(residuals**2)
print(fres)
fig, ax = plt.subplots() 
ax.scatter(xdata, ydata)
ax.plot(xdata, y, 'r', lw=2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2)
ax.set_xlim(0, 13)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$f(x, \beta)$", fontsize=18)
plt.show()

beta = (3, 4) 
def f(x, b0, b1):
    return b0 + b1 * np.log(x)
xdata = np.linspace(1, 12, 30) 
y = f(xdata, *beta) 
ydata = y + 0.05 * np.random.randn(len(xdata)) 
beta_opt, beta_cov = sp.optimize.curve_fit(f, xdata, ydata)
print(beta_opt)
lin_dev = sum(beta_cov[0]) 
print(lin_dev)
residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals**2)
print(fres)
fig, ax = plt.subplots()
ax. scatter(xdata, ydata)
ax. plot(xdata, y, 'r', lw=2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2) 
ax.set_xlim(0, 9)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$f(x, \beta)$", fontsize=18) 
plt.show()
 
beta = (5, 7) 
def f(x, b0, b1):
    return b0 * x ** b1
xdata = np.linspace(1, 10, 20)
y = f(xdata, *beta)
ydata = y + 0.05 * np.random.randn(len(xdata))
beta_opt, beta_cov = sp.optimize.curve_fit(f, xdata, ydata)
print(beta_opt) 
lin_dev = sum(beta_cov[0])
print(lin_dev)

residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals**2) 
print(fres)

fig, ax = plt.subplots()
ax. scatter(xdata, ydata)
ax. plot(xdata, y, 'r', lw=2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw=2) 
ax.set_xlim(0, 12)
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$f(x, \beta)$", fontsize=18) 
plt.show()
# Out:
# [0.22202199 0.75607628]
# 0.00012039352896410654
# 0.10586328046670054
# [0.21825214 0.75811436 0.49966238]
# 0.0005481580541448318
# 0.0894350893317696
# [2.97840749 4.00927681]
# 0.00022125691742456134
# 0.0503390481985305
# [4.99999977 7.00000002]
# 1.827545383090472e-14
# 0.05930532973706274

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = {
    'YearsExperience': [
        1.1, 1.3, 1.5, 2.0, 2.2, 2.9, 3.0, 3.2, 3.2, 3.7, 3.9, 4.0, 4.0, 4.1, 4.5, 4.9, 5.1, 5.3, 5.9, 6.0, 6.8, 7.1, 7.9, 8.2, 8.7,
        9.0, 9.5, 9.6, 10.3, 10.5
    ],
    'Salary': [
        39343.00, 46205.00, 37731.00, 43525.00, 39891.00, 56642.00, 60150.00, 54445.00, 64445.00, 57189.00, 63218.00, 55794.00, 56957.00, 57081.00, 61111.00, 67938.00, 66029.00, 83088.00, 81363.00, 93940.00, 91738.00, 98273.00, 101302.00,
        113812.00, 109431.00, 105582.00, 116969.00, 112635.00, 122391.00, 121872.00
    ]
}

dataset = pd.DataFrame(data)
dataset.head()
dataset.describe()

x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X_train, y_train)

print(regressor.intercept_)
print(regressor.coef_)

y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
df.plot(kind='bar')

plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
plt.scatter(X_test, y_test, color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()
# Out:
# LinearRegression()
# 26780.09915062818
# [9312.57512673]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns


y = [
    9.00, 9.00, 9.00, 7.50, 8.00, 10.00, 8.00, 8.00, 8.00, 7.00, 8.00, 7.50, 7.00, 7.00, 7.00, 7.00, 7.00, 7.00, 7.00, 8.50, 
    7.00, 8.00, 9.00, 9.00, 8.50, 9.00, 8.00, 7.50, 8.00, 9.00, 7.00, 7.00, 8.00, 7.50, 8.00, 6.58, 5.00, 7.00, 8.50, 7.00, 
    7.00, 7.00, 7.00, 7.00, 6.00, 9.00, 7.00, 7.00
]

x = [
    [
        3571, 4092, 3865, 4870, 4399, 5342, 5319, 5126, 4447, 4512, 4391, 5126, 4817, 4207, 4332, 4318, 4206, 3718, 4716, 
        4341, 4593, 4983, 4897, 4258, 4574, 3721, 3448, 3846, 4188, 3601, 3640, 3333, 3063, 3357, 3528, 3802, 4045, 3897, 
        3635, 4345, 4449, 3656, 4300, 3745, 5215, 4476, 4296, 5002
    ],
    [
        1976, 1250, 1586, 2351, 431, 1333, 11868, 2138, 8577, 8507, 5939, 14186, 6930, 6580, 8159, 10340, 8508, 4725, 5915, 
        6010, 7834, 602, 2449, 4686, 2619, 4746, 5399, 9061, 5975, 4650, 6905, 6594, 6524, 4121, 3495, 7834, 17782, 6385, 
        3274, 3905, 4639, 3985, 3635, 2611, 2302, 3942, 4083, 9794
    ],
    [
        5250, 5720, 5800, 5290, 5440, 5710, 4510, 5530, 5290, 5520, 5300, 5250, 5740, 5450, 6080, 5860, 5720, 5400, 7240, 
        6770, 6630, 6020, 5110, 5170, 5510, 5440, 5480, 5790, 5630, 4930, 5180, 5130, 5780, 5470, 4870, 6290, 5660, 5860, 
        6630, 6720, 6260, 5630, 6030, 5080, 6720, 5710, 6230, 5930
    ],
    [
        541, 524, 561, 414, 410, 457, 344, 467, 464, 498, 580, 471, 525, 508, 566, 635, 603, 714, 865, 640, 649, 540, 464, 
        547, 460, 566, 577, 631, 574, 534, 571, 554, 577, 628, 487, 644, 640, 704, 648, 968, 587, 699, 632, 591, 782, 510, 
        610, 524
    ]
]
url = 'https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv'
new_y = np.array(y)
dataset2 = pd.read_csv(url)

sns.heatmap(dataset2.corr(), cmap='coolwarm')
new_y = new_y.transpose()
df1 = pd.DataFrame(new_y)
new_x = np.array(x)
new_x = new_x.transpose()
df2 = pd.DataFrame(new_x)
df1 = df1.rename(columns= {0:'y'}, inplace= False)
df2 = df2.rename(columns={0:'x1', 1:'x2', 2:'x3', 3:'x4'}, inplace=False)

frames=[df1, df2]
dataset = pd.concat([df1, df2], axis=1, join="inner")
dataset.head()

print(dataset.shape)
dataset.describe()
x = dataset[['x1', 'x2', 'x3', 'x4']]
y = dataset['y']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(x_train, y_train)

coeff_df = pd.DataFrame(regressor.coef_, x.columns, columns=['Coefficient'])
print(coeff_df)

y_pred = regressor.predict(x_test)
y_pred = regressor.predict(x_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)

df.plot(kind='bar')
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# (48, 5)
#
# LinearRegression()
#     Coefficient
# x1    -0.000107
# x2    -0.000152
# x3     0.000211
# x4    -0.005058
#     Actual  Predicted
# 29     9.0   7.962130
# 4      8.0   9.252421
# 26     8.0   7.763302
# 30     7.0   7.481077
# 32     8.0   7.696914
# 37     7.0   7.003346
# 34     8.0   8.370428
# 40     7.0   7.885720
# 7      8.0   8.646102
# 10     8.0   7.527290

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([3.0, 3.2, 3.4, 3.6, 3.8, 4.0])
y = np.array([2.0, 3.0, 3.0, 3.0, 2.0, 4.0])

poly1_coeffs = np.polyfit(x, y, 1)
poly2_coeffs = np.polyfit(x, y, 2)

plt.figure(figsize=(8, 4))
plt.scatter(x, y, color='gray')

x_prec = np.linspace(2, 5, 100)
y_poly1 = np.polyval(poly1_coeffs, x_prec)
plt.plot(x_prec, y_poly1, color='blue', lw=2)

y_poly2 = np.polyval(poly2_coeffs, x_prec)
plt.plot(x_prec, y_poly2, color='red', lw=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()
